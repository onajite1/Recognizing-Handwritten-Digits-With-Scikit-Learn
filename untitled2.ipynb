# %%
from sklearn import svm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import load_digits
svc = svm.SVC(gamma=0.001,C=100.)
from sklearn import datasets
digits=load_digits()

# %%
digits
# Out:
# {'data': array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#         ...,
#         [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#         [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#         [ 0.,  0., 10., ..., 12.,  1.,  0.]]),
#  'target': array([0, 1, 2, ..., 8, 9, 8]),
#  'frame': None,
#  'feature_names': ['pixel_0_0',
#   'pixel_0_1',
#   'pixel_0_2',
#   'pixel_0_3',
#   'pixel_0_4',
#   'pixel_0_5',
#   'pixel_0_6',
#   'pixel_0_7',
#   'pixel_1_0',
#   'pixel_1_1',
#   'pixel_1_2',
#   'pixel_1_3',
#   'pixel_1_4',
#   'pixel_1_5',
#   'pixel_1_6',
#   'pixel_1_7',
#   'pixel_2_0',
#   'pixel_2_1',
#   'pixel_2_2',
#   'pixel_2_3',
#   'pixel_2_4',
#   'pixel_2_5',
#   'pixel_2_6',
#   'pixel_2_7',
#   'pixel_3_0',
#   'pixel_3_1',
#   'pixel_3_2',
#   'pixel_3_3',
#   'pixel_3_4',
#   'pixel_3_5',
#   'pixel_3_6',
#   'pixel_3_7',
#   'pixel_4_0',
#   'pixel_4_1',
#   'pixel_4_2',
#   'pixel_4_3',
# ...

# %%
digits.images[0]
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
plt.imshow(digits.images[0],cmap=plt.cm.gray_r,interpolation="nearest")

# %%
digits.target
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
digits.target.size
# Out:
# 1797

# %%
plt.subplot(321)
plt.imshow(digits.images[1791],cmap=plt.cm.gray_r,interpolation="nearest")
plt.subplot(322)
plt.imshow(digits.images[1792],cmap=plt.cm.gray_r,interpolation="nearest")
plt.subplot(323)
plt.imshow(digits.images[1793],cmap=plt.cm.gray_r,interpolation="nearest")
plt.subplot(324)
plt.imshow(digits.images[1794],cmap=plt.cm.gray_r,interpolation="nearest")
plt.subplot(325)
plt.imshow(digits.images[1795],cmap=plt.cm.gray_r,interpolation="nearest")
plt.subplot(326)
plt.imshow(digits.images[1796],cmap=plt.cm.gray_r,interpolation="nearest")

# %%
svc.fit(digits.data[1:1790], digits.target[1:1790])
# Out:
# SVC(C=100.0, gamma=0.001)

# %%
svc.predict(digits.data[1791:1796])
# Out:
# array([4, 9, 0, 8, 9])

# %%
digits.target[1791:1796]
# Out:
# array([4, 9, 0, 8, 9])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(digits.data,digits.target,test_size=0.25,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

# %%
Ir=LogisticRegression()

# %%
Ir.fit(x_train,y_train)
# Out:
# C:\Users\Onajite\Documents\Newfolder\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
pred=Ir.predict(x_test)
score=Ir.score(x_test,y_test)
score
# Out:
# 0.9511111111111111

# %%
import seaborn as sns
from sklearn import metrics
cm=metrics.confusion_matrix(y_test,pred)
plt.figure(figsize=(8,8))
sns.heatmap(cm,annot=True,fmt=".3f",linewidths=.5,square=True,cmap="RdPu",linecolor="black")
plt.ylabel("Actual Label")
plt.xlabel("Predicted Label")
all_sample_title="Accuracy_score : {0}".format(score)
plt.title(all_sample_title,size=15)
# Out:
# Text(0.5, 1.0, 'Accuracy_score : 0.9511111111111111')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(digits.data,digits.target,test_size=0.10,random_state=0)

# %%
pred=Ir.predict(x_test)
score=Ir.score(x_test,y_test)
score
# Out:
# 0.9666666666666667

# %%
import seaborn as sns
from sklearn import metrics
cm=metrics.confusion_matrix(y_test,pred)
plt.figure(figsize=(8,8))
sns.heatmap(cm,annot=True,fmt=".3f",linewidths=.5,square=True,cmap="RdPu",linecolor="black")
plt.ylabel("Actual Label")
plt.xlabel("Predicted Label")
all_sample_title="Accuracy_score : {0}".format(score)
plt.title(all_sample_title,size=15)
# Out:
# Text(0.5, 1.0, 'Accuracy_score : 0.9666666666666667')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(digits.data,digits.target,test_size=0.30,random_state=0)

# %%
pred=Ir.predict(x_test)
score=Ir.score(x_test,y_test)
score
# Out:
# 0.9592592592592593

# %%
import seaborn as sns
from sklearn import metrics
cm=metrics.confusion_matrix(y_test,pred)
plt.figure(figsize=(8,8))
sns.heatmap(cm,annot=True,fmt=".3f",linewidths=.5,square=True,cmap="RdPu",linecolor="black")
plt.ylabel("Actual Label")
plt.xlabel("Predicted Label")
all_sample_title="Accuracy_score : {0}".format(score)
plt.title(all_sample_title,size=15)
# Out:
# Text(0.5, 1.0, 'Accuracy_score : 0.9592592592592593')
